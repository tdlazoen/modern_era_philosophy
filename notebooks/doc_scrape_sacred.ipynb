# %% [markdown]
# ### This notebook scrapes the site http://sacred-texts.com/

# %%
import numpy as np
import pandas as pd
import requests
import urllib
from bs4 import BeautifulSoup
from collections import defaultdict
import sys
import os
sys.path.append(os.path.abspath('../scrapers'))
from dataframes import Philosophers, Documents
import re
import os
from string import punctuation

# %% [markdown]
# ### Loading Dataframes and Cleaning Documents

# %%
phils, docs = Philosophers(filepath='../data/philosophers.csv'), Documents(filepath='../data/documents.csv')

# %%
phils.df.head()
# Out:
#                 name  year_born  year_died  century  time_period      era  \
# 0  thales of miletos       -624       -546     -500  presocratic  ancient
# 1        anaximander       -610       -546     -500  presocratic  ancient
# 2         anaximenes       -585       -525     -500  presocratic  ancient
# 3         pythagoras       -570       -490     -500  presocratic  ancient
# 4         heraclitus       -535       -475     -500  presocratic  ancient
#
#                                           image_path
# 0  /Users/tylerlazoen/philosophy_capstone/images/...
# 1  /Users/tylerlazoen/philosophy_capstone/images/...
# 2  /Users/tylerlazoen/philosophy_capstone/images/...
# 3  /Users/tylerlazoen/philosophy_capstone/images/...
# 4  /Users/tylerlazoen/philosophy_capstone/images/...

# %%
print(docs.df.shape)
docs.df.head()
# Out:
# (170, 6)
#                              title               author  year  \
# 0                       the prince  niccolo machiavelli  1532
# 1                  the new organon        francis bacon  1620
# 2          selected correspondence       rene descartes  1619
# 3          discourse on the method       rene descartes  1637
# 4  meditations on first philosophy       rene descartes  1641
#
#                                                 text  \
# 0  the prince niccol machiavelli copyright 201020...
# 1  or true directions concerning the interpretati...
# 2  selected correspondence of descartes ren desca...
# 3  discourse on the method of rightly conducting ...
# 4  in which are demonstrated the existence of god...
#
#                                                  url  \
# 0  http://www.earlymoderntexts.com/assets/pdfs/ma...
# 1  http://www.earlymoderntexts.com/assets/pdfs/ba...
# 2  http://www.earlymoderntexts.com/assets/pdfs/de...
# 3  http://www.earlymoderntexts.com/assets/pdfs/de...
# 4  http://www.earlymoderntexts.com/assets/pdfs/de...
#
#                                             filepath
# 0  /Users/tylerlazoen/philosophy_capstone/pdfs/ma...
# 1  /Users/tylerlazoen/philosophy_capstone/pdfs/ba...
# 2  /Users/tylerlazoen/philosophy_capstone/pdfs/de...
# 3  /Users/tylerlazoen/philosophy_capstone/pdfs/de...
# 4  /Users/tylerlazoen/philosophy_capstone/pdfs/de...

# %%
last_title = docs.df.title.values[0]
for title in docs.df.title.values[1:]:
    if last_title[:8] in title:
        print(title)
    last_title = title

# leviathan, essay concerning human understanding, new essays on human understanding,
# essays on the intellectual powers of man, essays on the active powers of man,
# a treatise to human nature, an inquiry into the nature and causes of the wealth of nations
# a critique of pure reason, a system of logic
# Out:
# leviathan part 2
# leviathan part 3
# leviathan part 4
# objections to the meditations, and descartes' replies
# second treatise of government
# essay concerning human understanding part 2
# essay concerning human understanding part 3
# essay concerning human understanding part 4
# new essays on human understanding book 2
# new essays on human understanding book 3
# new essays on human understanding book 4
# exchange of papers with leibniz
# an inquiry concerning virtue and morality
# essays on the intellectual powers of man essay 2
# essays on the intellectual powers of man essay 3
# essays on the intellectual powers of man essay 4
# essays on the intellectual powers of man essay 5
# essays on the intellectual powers of man essay 6
# essays on the intellectual powers of man essay 7
# essays on the active powers of man essay 1
# essays on the active powers of man essay 2
# essays on the active powers of man essay 3
# essays on the active powers of man essay 4
# essays on the active powers of man essay 5
# a treatise of human nature book ii
# a treatise of human nature book iii
# an enquiry concerning the principles of morals
# an inquiry into the nature and causes of the wealth of nations book ii
# an inquiry into the nature and causes of the wealth of nations books iii and iv
# an inquiry into the nature and causes of the wealth of nations book v
# the critique of pure reason second part
# a system of logic book ii
# a system of logic book iii
# a system of logic book iv

# %%
part_texts = ['leviathan', 'essay concerning human understanding', 'new essays on human understanding',\
              'essays on the intellectual powers of man', 'essays on the active powers of man', \
              'a treatise of human nature', 'an inquiry into the nature and causes of the wealth of nations', \
              'the critique of pure reason', 'a system of logic']

# %%
for text_name in part_texts:
    lst_title = [x for x in docs.df.title.values if x[:len(text_name)] == text_name]
    idxs = [docs.df[docs.df.title == x].index[0] for x in lst_title]
    author = docs.df.loc[idxs[0], 'author']
    year = docs.df.loc[idxs[0], 'year']
    text = ''
    pdfs = []
    urls = []
    for idx in idxs:
        text += docs.df.loc[idx, 'text']
        pdfs.append(docs.df.loc[idx, 'filepath'])
        urls.append(docs.df.loc[idx, 'url'])
        
    new_entry = {'title': text_name,
                 'author': author,
                 'year': year,
                 'text': text,
                 'url': urls,
                 'filepath': pdfs}
    docs.df = docs.df.append(new_entry, ignore_index=True)
    docs.df.drop(idxs, inplace=True)

# %%
docs.save_df()

# %% [markdown]
# ### Scraping Sacred Texts

# %%
base_url = 'http://sacred-texts.com/phi/'
r = requests.get(base_url)
soup = BeautifulSoup(r.content, 'lxml')

# %%
names = [x.get_text().strip() for x in soup.select('h3')][:-1]
names.remove('Epicurus')
new_names = []
titles_dates = [x.get_text() for x in soup.select('span.c_e')]
links = [x['href'].strip() for x in soup.select('span.c_e a')]
links

i = 0
titles = []
dates = []
for name in names:

    if i == 70: 
        break
    link_base = re.split(r'/', links[i])[0]
    
    for entry in titles_dates[i:]:
        
        if link_base in links[i]:
            if i == 9:
                name = 'Epicurus'
                
            new_names.append(name)

            title = re.split(r'[[\]]', entry)[0].strip()

            if title == 'Discourse on the Method of Rightly Conducting the Reason, and Seeking Truth in the Sciences':
                title = 'Discourse on the Method'
            
            try:
                date = re.split(r'[[\]]', entry)[1]
                if 'BCE' in date:
                    date = -1 * int(filter(str.isdigit, date))
                else:
                    date = int(filter(str.isdigit, date))
                dates.append(date)
            except IndexError:
                dates.append(0)
            titles.append(title)
            i += 1
        else:
            break

links = ['http://sacred-texts.com/phi/' + x for x in links]
links = [x.replace('phi/../', '') if '..' in x else x for x in links]
idxs = [links.index(x) for x in links if 'spinoza' in x]
for i, idx in enumerate(idxs):
    new_names.pop(idx-i)
    titles.pop(idx-i)
    dates.pop(idx-i)
    links.pop(idx-i)
    
print(len(new_names))
print(len(titles))
print(len(dates))
links
# Out:
# 67
# 67
# 67
# ['http://sacred-texts.com/phi/berkeley/three.txt',
#  'http://sacred-texts.com/phi/berkeley/treatise.txt',
#  'http://sacred-texts.com/phi/desc/disc.txt',
#  'http://sacred-texts.com/cla/plato/symposiu.htm',
#  'http://sacred-texts.com/cla/plato/theaetet.htm',
#  'http://sacred-texts.com/cla/plato/timaeus.htm',
#  'http://sacred-texts.com/phi/thoreau/plea.txt',
#  'http://sacred-texts.com/phi/thoreau/slavery.txt',
#  'http://sacred-texts.com/phi/thoreau/life.txt',
#  'http://sacred-texts.com/phi/thoreau/civil.txt',
#  'http://sacred-texts.com/phi/thoreau/walden.txt']

# %% [markdown]
# ### Add Documents to Dataframe

# %%
for i in range(len(links)):
    url = links[i]
    author = new_names[i].lower()
    title = titles[i].lower()
    year = dates[i]
    text = []
    
    if title not in docs.df.title.values:
        print('\n{} documents remaining'.format(len(links) - i))
        filepath = os.path.expanduser('~') + '/philosophy_capstone/text_files/' + title.lower()
        print('Downloading file for {}'.format(title))
        urllib.urlretrieve(url, filepath)
        with open(filepath) as f:
            text = f.read()
        text = docs.clean_text(text)
        print('Adding Document')
        docs.add_document(author, title, year, text, url, filepath=filepath)
# Out:
# 66 documents remaining
# Downloading file for a treatise concerning the principles of human knowledge
# Adding Document
#
# 63 documents remaining
# Downloading file for the transcendalist
# Adding Document
#
# 62 documents remaining
# Downloading file for essays, first series
# Adding Document
#
# 61 documents remaining
# Downloading file for essays, second series
# Adding Document
#
# 60 documents remaining
# Downloading file for the enchiridion
# Adding Document
#
# 59 documents remaining
# Downloading file for the discourses
# Adding Document
#
# 58 documents remaining
# Downloading file for letter to menoeceus
# Adding Document
#
# 56 documents remaining
# Downloading file for of superstition and enthusiasm
# Adding Document
#
# 55 documents remaining
# Downloading file for of the delicacy of taste and passion
# Adding Document
#
# 54 documents remaining
# Downloading file for of the liberty of the press
# Adding Document
#
# 53 documents remaining
# Downloading file for of essay writing
# Adding Document
#
# 52 documents remaining
# Downloading file for of the rise and progress of the arts and sciences
# Adding Document
#
# 50 documents remaining
# Downloading file for a letter from a gentleman
# Adding Document
#
# 49 documents remaining
# Downloading file for essays on suicide and the immortality of the soul
# Adding Document
#
# 48 documents remaining
# Downloading file for the natural history of religion
# Adding Document
#
# 47 documents remaining
# Downloading file for of tragedy
# Adding Document
#
# 46 documents remaining
# Downloading file for of the standard of taste
# Adding Document
#
# 45 documents remaining
# Downloading file for my own life
# Adding Document
#
# 43 documents remaining
# Downloading file for the critique of judgement
# Adding Document
#
# 42 documents remaining
# Downloading file for the critique of practical reason
# Adding Document
#
# 40 documents remaining
# Downloading file for fundamental principles of the metaphysic of morals
# Adding Document
#
# 39 documents remaining
# Downloading file for introduction to the metaphysic of morals
# Adding Document
#
# 38 documents remaining
# Downloading file for the metaphysical elements of ethics
# Adding Document
#
# 37 documents remaining
# Downloading file for prolegomena to any future metaphysics
# Adding Document
#
# 36 documents remaining
# Downloading file for the science of right
# Adding Document
#
# 35 documents remaining
# Downloading file for the monadology
# Adding Document
#
# 34 documents remaining
# Downloading file for on liberty
# Adding Document
#
# 33 documents remaining
# Downloading file for representative government
# Adding Document
#
# 31 documents remaining
# Downloading file for thus spake zarathustra
# Adding Document
#
# 30 documents remaining
# Downloading file for the provincial letters
# Adding Document
#
# 29 documents remaining
# Downloading file for pensees
# Adding Document
#
# 28 documents remaining
# Downloading file for cratylus
# Adding Document
#
# 27 documents remaining
# Downloading file for charmides, or temperance
# Adding Document
#
# 26 documents remaining
# Downloading file for critias
# Adding Document
#
# 25 documents remaining
# Downloading file for crito
# Adding Document
#
# 24 documents remaining
# Downloading file for euthydemus
# Adding Document
#
# 23 documents remaining
# Downloading file for euthyphro
# Adding Document
#
# 22 documents remaining
# Downloading file for gorgias
# Adding Document
#
# 21 documents remaining
# Downloading file for ion
# Adding Document
#
# 20 documents remaining
# Downloading file for laches, or courage
# Adding Document
#
# 19 documents remaining
# Downloading file for laws
# Adding Document
#
# 18 documents remaining
# Downloading file for lysis, or friendship
# Adding Document
#
# 17 documents remaining
# Downloading file for meno
# Adding Document
#
# 16 documents remaining
# Downloading file for parmenides
# Adding Document
#
# 15 documents remaining
# Downloading file for phaedo
# Adding Document
#
# 14 documents remaining
# Downloading file for phaedrus
# Adding Document
#
# 13 documents remaining
# Downloading file for philebus
# Adding Document
#
# 12 documents remaining
# Downloading file for protagoras
# Adding Document
#
# 11 documents remaining
# Downloading file for the seventh letter
# Adding Document
#
# 10 documents remaining
# Downloading file for sophist
# Adding Document
#
# 9 documents remaining
# Downloading file for statesman
# Adding Document
#
# 8 documents remaining
# Downloading file for symposium
# Adding Document
#
# 7 documents remaining
# Downloading file for theaetetus
# Adding Document
#
# 6 documents remaining
# Downloading file for timaeus
# Adding Document
#
# 5 documents remaining
# Downloading file for a plea for captain john brown
# Adding Document
#
# 4 documents remaining
# Downloading file for slavery in massachusetts
# Adding Document
#
# 3 documents remaining
# Downloading file for life without principle
# Adding Document
#
# 2 documents remaining
# Downloading file for civil disobedience
# Adding Document
#
# 1 documents remaining
# Downloading file for walden, or life in the woods
# Adding Document

# %%
print(docs.df.shape)
docs.df.tail()
# Out:
# (158, 6)
#                              title               author  year  \
# 153  a plea for captain john brown  henry david thoreau  1853
# 154       slavery in massachusetts  henry david thoreau  1854
# 155         life without principle  henry david thoreau  1863
# 156             civil disobedience  henry david thoreau  1849
# 157   walden, or life in the woods  henry david thoreau  1854
#
#                                                   text  \
# 153  1853 a plea for captain john brown by henry da...
# 154  1854 slavery in massachusetts by henry david t...
# 155  1863 life without principle by henry david tho...
# 156  1849 civil disobedience by henry david thoreau...
# 157  1854 walden or life in the woods by henry davi...
#
#                                                  url  \
# 153     http://sacred-texts.com/phi/thoreau/plea.txt
# 154  http://sacred-texts.com/phi/thoreau/slavery.txt
# 155     http://sacred-texts.com/phi/thoreau/life.txt
# 156    http://sacred-texts.com/phi/thoreau/civil.txt
# 157   http://sacred-texts.com/phi/thoreau/walden.txt
#
#                                               filepath
# 153  /Users/tylerlazoen/philosophy_capstone/text_fi...
# 154  /Users/tylerlazoen/philosophy_capstone/text_fi...
# 155  /Users/tylerlazoen/philosophy_capstone/text_fi...
# 156  /Users/tylerlazoen/philosophy_capstone/text_fi...
# 157  /Users/tylerlazoen/philosophy_capstone/text_fi...

# %%
docs.save_df()
