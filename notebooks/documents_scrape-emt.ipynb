# %% [markdown]
# ### This Notebook scrapes http://www.earlymoderntexts.com/
# ### And Creates Dataframes/CSV Files For Later Use

# %%
import requests
from bs4 import BeautifulSoup
from unidecode import unidecode
from collections import defaultdict
from string import punctuation
import urllib
import os
import re
import time
import sys
import os
sys.path.append(os.path.abspath('../scrapers'))
import philosopher_profile_data as ppd

# %% [markdown]
# ### Add New Philosophers on Page to Philosophers Dictionary

# %%
philosophers = ppd.western_philosophers()

# %%
url = 'http://www.earlymoderntexts.com/texts'
time.sleep(1)
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

# %%
authors = [unidecode(x.string) for x in soup.select('li b')]
authors.remove('Isaac Newton (1642-1727)')
authors.remove('Sophie de Grouchy (1764-1822)')
years = [filter(str.isdigit, x) for x in authors]
lifespans = [(x[:4], x[4:]) for x in years]
authors = [re.split(r'[()]', x)[0].strip() for x in authors]
idx = authors.index('Anthony Ashley Cooper, third Earl of Shaftesbury')
authors[idx] = 'Anthony Ashley Cooper'
birth_years = [int(x[0]) for x in lifespans]
death_years = [int(x[1]) for x in lifespans]

# %%
print(len(authors))
print(len(birth_years))
print(len(death_years))
for i in range(len(authors)):
    print('\nAuthor: {}, Year Born: {}, Year Died: {}'.format(authors[i], birth_years[i], death_years[i]))
# Out:
# 31
# 31
# 31
#
# Author: Niccolo Machiavelli, Year Born: 1469, Year Died: 1527
#
# Author: Francis Bacon, Year Born: 1561, Year Died: 1626
#
# Author: Thomas Hobbes, Year Born: 1588, Year Died: 1679
#
# Author: Rene Descartes, Year Born: 1596, Year Died: 1650
#
# Author: Robert Boyle, Year Born: 1627, Year Died: 1691
#
# Author: Anne Conway, Year Born: 1631, Year Died: 1679
#
# Author: Baruch Spinoza, Year Born: 1632, Year Died: 1677
#
# Author: John Locke, Year Born: 1632, Year Died: 1704
#
# Author: Nicolas Malebranche, Year Born: 1638, Year Died: 1715
#
# Author: Gottfried Wilhelm Leibniz, Year Born: 1646, Year Died: 1716
#
# Author: Anthony Ashley Cooper, Year Born: 1671, Year Died: 1713
#
# Author: Samuel Clarke, Year Born: 1675, Year Died: 1729
#
# Author: George Berkeley, Year Born: 1685, Year Died: 1753
#
# Author: Joseph Butler, Year Born: 1692, Year Died: 1752
#
# Author: Francis Hutcheson, Year Born: 1694, Year Died: 1746
#
# Author: Jonathan Edwards, Year Born: 1703, Year Died: 1758
#
# Author: Julien Offray de La Mettrie, Year Born: 1709, Year Died: 1751
#
# Author: Thomas Reid, Year Born: 1710, Year Died: 1796
#
# Author: David Hume, Year Born: 1711, Year Died: 1776
#
# Author: Jean-Jacques Rousseau, Year Born: 1712, Year Died: 1778
#
# Author: Adam Smith, Year Born: 1723, Year Died: 1790
#
# Author: Richard Price, Year Born: 1723, Year Died: 1791
#
# Author: Immanuel Kant, Year Born: 1724, Year Died: 1804
#
# Author: Moses Mendelssohn, Year Born: 1729, Year Died: 1786
#
# Author: Edmund Burke, Year Born: 1729, Year Died: 1797
#
# Author: Nicolas de Condorcet, Year Born: 1743, Year Died: 1794
#
# Author: Jeremy Bentham, Year Born: 1748, Year Died: 1832
#
# Author: Mary Wollstonecraft, Year Born: 1759, Year Died: 1797
#
# Author: Benjamin Constant, Year Born: 1767, Year Died: 1830
#
# Author: John Stuart Mill, Year Born: 1806, Year Died: 1873
#
# Author: Henry Sidgwick, Year Born: 1838, Year Died: 1900

# %%
print(len(authors))
print(len(philosophers))
print(len([author for author in authors if author not in philosophers.keys()]))
# Out:
# 31
# 83
# 16

# %%
for i in range(len(authors)):
    if authors[i] not in philosophers.keys():
        philosophers = ppd.add_new(philosophers, authors[i], birth_years[i], death_years[i])

# %%
print(len(philosophers))
print(len([x for x in philosophers if philosophers[x]['time_period'] == None]))
# Out:
# 99
# 0

# %%
philosophers
# Out:
# DefaultOrderedDict([('Thales of Miletos',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thales_of_miletos.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -624,
#                       'year_died': -546}),
#                     ('Anaximander',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anaximander.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -610,
#                       'year_died': -546}),
#                     ('Anaximenes',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anaximenes.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -585,
#                       'year_died': -525}),
#                     ('Pythagoras',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/pythagoras.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -570,
#                       'year_died': -490}),
#                     ('Heraclitus',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/heraclitus.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -535,
#                       'year_died': -475}),
#                     ('Parmenides of Elea',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/parmenides_of_elea.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -515,
#                       'year_died': -450}),
#                     ('Anaxagoras',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anaxagoras.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -500,
#                       'year_died': -428}),
#                     ('Empedocles',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/empedocles.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -490,
#                       'year_died': -430}),
#                     ('Zeno of Elea',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/zeno_of_elea.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -490,
#                       'year_died': -430}),
#                     ('Protagoras',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/protagoras.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -490,
#                       'year_died': -420}),
#                     ('Gorgias',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gorgias.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -487,
#                       'year_died': -376}),
#                     ('Democritus',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/democritus.jpg',
#                       'time_period': 'presocratic',
#                       'year_born': -460,
#                       'year_died': -370}),
#                     ('Socrates',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/socrates.jpg',
#                       'time_period': 'socratic',
#                       'year_born': -469,
#                       'year_died': -399}),
#                     ('Plato',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/plato.jpg',
#                       'time_period': 'socratic',
#                       'year_born': -428,
#                       'year_died': -348}),
#                     ('Diogenes of Sinope',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/diogenes_of_sinope.jpg',
#                       'time_period': 'socratic',
#                       'year_born': -412,
#                       'year_died': -323}),
#                     ('Aristotle',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/aristotle.jpg',
#                       'time_period': 'socratic',
#                       'year_born': -384,
#                       'year_died': -322}),
#                     ('Thucydides',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thucydides.jpg',
#                       'time_period': 'socratic',
#                       'year_born': -460,
#                       'year_died': -400}),
#                     ('Pyrrho',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/pyrrho.jpg',
#                       'time_period': 'hellenistic',
#                       'year_born': -360,
#                       'year_died': -270}),
#                     ('Epicurus',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/epicurus.jpg',
#                       'time_period': 'hellenistic',
#                       'year_born': -341,
#                       'year_died': -270}),
#                     ('Zeno of Citium',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/zeno_of_citium.jpg',
#                       'time_period': 'hellenistic',
#                       'year_born': -334,
#                       'year_died': -262}),
#                     ('Philo',
#                      {'Nationality': 'Egyptian-Jewish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/philo.jpg',
#                       'time_period': 'hellenistic',
#                       'year_born': -20,
#                       'year_died': 50}),
#                     ('Plotinus',
#                      {'Nationality': 'Egyptian-Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/plotinus.jpg',
#                       'time_period': 'hellenistic',
#                       'year_born': 204,
#                       'year_died': 270}),
#                     ('Marcus Tullius Cicero',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/marcus_tullius_cicero.jpg',
#                       'time_period': 'roman',
#                       'year_born': -106,
#                       'year_died': -43}),
#                     ('Epictetus',
#                      {'Nationality': 'Greek-Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/epictetus.jpg',
#                       'time_period': 'roman',
#                       'year_born': 55,
#                       'year_died': 135}),
#                     ('Marcus Aurelius',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/marcus_aurelius.jpg',
#                       'time_period': 'roman',
#                       'year_born': 55,
#                       'year_died': 135}),
#                     ('St. Augustine of Hippo',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/st._augustine_of_hippo.jpg',
#                       'time_period': 'roman',
#                       'year_born': 354,
#                       'year_died': 430}),
#                     ('Boethius',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/boethius.jpg',
#                       'time_period': 'roman',
#                       'year_born': 480,
#                       'year_died': 525}),
#                     ('Avicenna',
#                      {'Nationality': 'Persian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/avicenna.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 980,
#                       'year_died': 1037}),
#                     ('St. Anselm',
#                      {'Nationality': 'Italian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/st._anselm.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1033,
#                       'year_died': 1109}),
#                     ('Peter Abelard',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/peter_abelard.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1079,
#                       'year_died': 1142}),
#                     ('Averroes',
#                      {'Nationality': 'Spanish-Arabic',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/averroes.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1126,
#                       'year_died': 1198}),
#                     ('Maimonides',
#                      {'Nationality': 'Spanish-Jewish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/maimonides.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1135,
#                       'year_died': 1204}),
#                     ('Albertus Magnus',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/albertus_magnus.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1200,
#                       'year_died': 1280}),
#                     ('Roger Bacon',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/roger_bacon.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1214,
#                       'year_died': 1294}),
#                     ('St. Thomas Aquinas',
#                      {'Nationality': 'Italian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/st._thomas_aquinas.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1225,
#                       'year_died': 1274}),
#                     ('John Duns Scotus',
#                      {'Nationality': 'Scottish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_duns_scotus.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1266,
#                       'year_died': 1308}),
#                     ('William of Ockham',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/william_of_ockham.jpg',
#                       'time_period': 'medieval',
#                       'year_born': 1285,
#                       'year_died': 1348}),
#                     ('Desiderius Erasmus',
#                      {'Nationality': 'Dutch',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/desiderius_erasmus.jpg',
#                       'time_period': 'renaissance',
#                       'year_born': 1466,
#                       'year_died': 1536}),
#                     ('Niccolo Machiavelli',
#                      {'Nationality': 'Italian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/niccolo_machiavelli.jpg',
#                       'time_period': 'renaissance',
#                       'year_born': 1469,
#                       'year_died': 1527}),
#                     ('Thomas More',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thomas_more.jpg',
#                       'time_period': 'renaissance',
#                       'year_born': 1478,
#                       'year_died': 1535}),
#                     ('Francis Bacon',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/francis_bacon.jpg',
#                       'time_period': 'renaissance',
#                       'year_born': 1561,
#                       'year_died': 1626}),
#                     ('Thomas Hobbes',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thomas_hobbes.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1588,
#                       'year_died': 1679}),
#                     ('Rene Descartes',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/rene_descartes.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1596,
#                       'year_died': 1650}),
#                     ('Blaise Pascal',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/blaise_pascal.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1623,
#                       'year_died': 1662}),
#                     ('Baruch Spinoza',
#                      {'Nationality': 'Dutch-Jewish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/baruch_spinoza.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1623,
#                       'year_died': 1677}),
#                     ('John Locke',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_locke.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1632,
#                       'year_died': 1704}),
#                     ('Nicolas Malebranche',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/nicolas_malebranche.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1638,
#                       'year_died': 1715}),
#                     ('Gottfried Wilhelm Leibniz',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gottfried_wilhelm_leibniz.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1646,
#                       'year_died': 1716}),
#                     ('Bishop George Berkeley',
#                      {'Nationality': 'Irish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/bishop_george_berkeley.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1685,
#                       'year_died': 1753}),
#                     ('Voltaire',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/voltaire.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1694,
#                       'year_died': 1778}),
#                     ('David Hume',
#                      {'Nationality': 'Scottish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/david_hume.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1711,
#                       'year_died': 1776}),
#                     ('Jean-Jacques Rousseau',
#                      {'Nationality': 'Swiss-French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jean-jacques_rousseau.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1712,
#                       'year_died': 1778}),
#                     ('Adam Smith',
#                      {'Nationality': 'Scottish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/adam_smith.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1723,
#                       'year_died': 1790}),
#                     ('Immanuel Kant',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/immanuel_kant.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1724,
#                       'year_died': 1804}),
#                     ('Edmund Burke',
#                      {'Nationality': 'Irish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/edmund_burke.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1729,
#                       'year_died': 1797}),
#                     ('Jeremy Bentham',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jeremy_bentham.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1748,
#                       'year_died': 1832}),
#                     ('Johann Gottlieb Fichte',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/johann_gottlieb_fichte.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1762,
#                       'year_died': 1814}),
#                     ('G.W.F. Hegel',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/g.w.f._hegel.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1770,
#                       'year_died': 1831}),
#                     ('Friedrich Schelling',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/friedrich_schelling.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1775,
#                       'year_died': 1854}),
#                     ('Arthur Schopenhauer',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/arthur_schopenhauer.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1788,
#                       'year_died': 1860}),
#                     ('Auguste Comte',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/auguste_comte.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1798,
#                       'year_died': 1857}),
#                     ('Ralph Waldo Emerson',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/ralph_waldo_emerson.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1803,
#                       'year_died': 1882}),
#                     ('John Stuart Mill',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_stuart_mill.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1806,
#                       'year_died': 1873}),
#                     ('Soren Kierkegaard',
#                      {'Nationality': 'Danish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/soren_kierkegaard.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1813,
#                       'year_died': 1855}),
#                     ('Henry David Thoreau',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/henry_david_thoreau.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1817,
#                       'year_died': 1862}),
#                     ('Karl Marx',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/karl_marx.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1818,
#                       'year_died': 1883}),
#                     ('Charles Sanders Peirce',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/charles_sanders_peirce.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1839,
#                       'year_died': 1914}),
#                     ('William James',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/william_james.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1842,
#                       'year_died': 1910}),
#                     ('Friedrich Nietzsche',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/friedrich_nietzsche.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1844,
#                       'year_died': 1900}),
#                     ('Gottlob Frege',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gottlob_frege.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1848,
#                       'year_died': 1925}),
#                     ('John Dewey',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_dewey.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1859,
#                       'year_died': 1952}),
#                     ('Edmund Husserl',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/edmund_husserl.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1859,
#                       'year_died': 1938}),
#                     ('Alfred North Whitehead',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/alfred_north_whitehead.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1861,
#                       'year_died': 1947}),
#                     ('Bertrand Russell',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/bertrand_russell.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1872,
#                       'year_died': 1970}),
#                     ('George Edward Moore',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/george_edward_moore.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1873,
#                       'year_died': 1958}),
#                     ('Ludwig Wittgenstein',
#                      {'Nationality': 'Austrian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/ludwig_wittgenstein.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1889,
#                       'year_died': 1951}),
#                     ('Martin Heidegger',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/martin_heidegger.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1889,
#                       'year_died': 1976}),
#                     ('Gilbert Ryle',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gilbert_ryle.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1900,
#                       'year_died': 1976}),
#                     ('Jean-Paul Sartre',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jean-paul_sartre.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1905,
#                       'year_died': 1980}),
#                     ('Willard Van Orman Quine',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/willard_van_orman_quine.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1908,
#                       'year_died': 2000}),
#                     ('Alfred Ayer',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/alfred_ayer.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1910,
#                       'year_died': 1989}),
#                     ('Michel Foucault',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/michel_foucault.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1926,
#                       'year_died': 1984}),
#                     ('Jacques Derrida',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jacques_derrida.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1930,
#                       'year_died': 2004}),
#                     ('Robert Boyle',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/robert_boyle.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1627,
#                       'year_died': 1691}),
#                     ('Anne Conway',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anne_conway.jpg',
#                       'time_period': 'reason',
#                       'year_born': 1631,
#                       'year_died': 1679}),
#                     ('Anthony Ashley Cooper',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anthony_ashley_cooper.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1671,
#                       'year_died': 1713}),
#                     ('Samuel Clarke',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/samuel_clarke.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1675,
#                       'year_died': 1729}),
#                     ('George Berkeley',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/george_berkeley.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1685,
#                       'year_died': 1753}),
#                     ('Joseph Butler',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/joseph_butler.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1692,
#                       'year_died': 1752}),
#                     ('Francis Hutcheson',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/francis_hutcheson.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1694,
#                       'year_died': 1746}),
#                     ('Jonathan Edwards',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jonathan_edwards.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1703,
#                       'year_died': 1758}),
#                     ('Julien Offray de La Mettrie',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/julien_offray_de_la_mettrie.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1709,
#                       'year_died': 1751}),
#                     ('Thomas Reid',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thomas_reid.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1710,
#                       'year_died': 1796}),
#                     ('Richard Price',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/richard_price.jpg',
#                       'time_period': 'enlightenment',
#                       'year_born': 1723,
#                       'year_died': 1791}),
#                     ('Moses Mendelssohn',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/moses_mendelssohn.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1729,
#                       'year_died': 1786}),
#                     ('Nicolas de Condorcet',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/nicolas_de_condorcet.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1743,
#                       'year_died': 1794}),
#                     ('Mary Wollstonecraft',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/mary_wollstonecraft.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1759,
#                       'year_died': 1797}),
#                     ('Benjamin Constant',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/benjamin_constant.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1767,
#                       'year_died': 1830}),
#                     ('Henry Sidgwick',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/henry_sidgwick.jpg',
#                       'time_period': 'modern',
#                       'year_born': 1838,
#                       'year_died': 1900})])

# %% [markdown]
# ### Create Documents Dictionary and Define Necessary Functions

# %%
documents = defaultdict(dict)

# %%
def add_document(dct, author, title, year, url, filepath):
    idx = len(dct)
    dct[idx]['title'] = title
    dct[idx]['author'] = author
    dct[idx]['year'] = year
    dct[idx]['pdf_url'] = url
    dct[idx]['pdf_file'] = filepath
    
    return dct

# %%
def get_pdfs(author):
    base_link = 'http://www.earlymoderntexts.com/authors/'
    author_link = None

    if author == 'Julien Offray de La Mettrie':
        author_link = base_link + 'lamettrie'
        
    elif author == 'Anthony Ashley Cooper':
        author_link = base_link + 'shaftesbury'
        
    else:
        name_split = author.split()
        last_name = name_split[-1].lower().strip()
        author_link = base_link + last_name
    
    url = author_link
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')

    text_author = unidecode(soup.select('div.content h2')[0].get_text())
    text_author = re.split(r',', text_author)[0]

    titles = [unidecode(x.get_text()) for x in soup.select('li b')]
    
    if author == 'Thomas Hobbes':
        title = titles[0]
        titles = []
        for i in range(1, 5):
            titles.append(title + ' Part {}'.format(i))
    
    elif author == 'John Locke':
        idx = titles.index('Essay Concerning Human Understanding')
        for i in range(1, 5):
            title = 'Essay Concerning Human Understanding' + ' Part {}'.format(i)
            titles.insert(idx + (i-1), title)
        titles.remove('Essay Concerning Human Understanding')
    
    elif author == 'Gottfried Wilhelm Leibniz':
        idx = titles.index('New Essays on Human Understanding')
        for i in range(1, 5):
            title = 'New Essays on Human Understanding' + ' Book {}'.format(i)
            titles.insert(idx + (i-1), title)
        titles.remove('New Essays on Human Understanding')
        
    elif author == 'Thomas Reid':
        idx1 = titles.index('Essays on the Intellectual Powers of Man')
        
        for i in range(1, 8):
            title = 'Essays on the Intellectual Powers of Man' + ' Essay {}'.format(i)
            titles.insert(idx1 + (i-1), title)

        idx2 = titles.index('Essays on the Active Powers of Man')
        
        for i in range(1, 6):
            title = 'Essays on the Active Powers of Man' + ' Essay {}'.format(i)
            titles.insert(idx2 + (i-1), title)
            
        titles.remove('Essays on the Intellectual Powers of Man')
        titles.remove('Essays on the Active Powers of Man')
    
    elif author == 'David Hume':
        idx = titles.index('A Treatise of Human Nature')
        books = ['I', 'II', 'III']
        
        for i, book in enumerate(books):
            title = 'A Treatise of Human Nature' + ' Book ' + book
            titles.insert(idx + (i), title)
            
        titles.remove('A Treatise of Human Nature')
    
    elif author == 'Adam Smith':
        idx = titles.index('An Inquiry into the Nature and Causes of the Wealth of Nations')
        books = ['Book I', 'Book II', 'Books III and IV', 'Book V']
        
        for i, book in enumerate(books):
            title = 'An Inquiry into the Nature and Causes of the Wealth of Nations' + ' ' + book
            titles.insert(idx + (i), title)
        
        titles.remove('An Inquiry into the Nature and Causes of the Wealth of Nations')
    
    elif author == 'Immanuel Kant':
        idx = titles.index('The Critique of Pure Reason')
        parts = ['First Part', 'Second Part']
        
        for i, part in enumerate(parts):
            title = 'The Critique of Pure Reason' + ' ' + part
            titles.insert(idx + (i), title)
        
        titles.remove('The Critique of Pure Reason')
    
    elif author == 'John Stuart Mill':
        idx1 = titles.index('A System of Logic')
        books = ['I', 'II', 'III', 'IV']
        
        for i, book in enumerate(books):
            title = 'A System of Logic' + ' Book ' + book
            titles.insert(idx1 + (i), title)
        
        idx2 = titles.index('Three Essays on Religion')
        books = ['Helen Taylor\'s Introduction to the Essays', 'Nature', 'The Usefulness of Religion', \
                'Theism']
        
        for i, book in enumerate(books):
            title = book
            titles.insert(idx2 + (i), title)
        
        titles.remove('A System of Logic')
        titles.remove('Three Essays on Religion')
            
    long_titles = [unidecode(x.get_text()) for x in soup.select('li')]
    year_pub = []
    
    for title in titles:
        
        if author == 'Thomas Hobbes':
            year_pub.append(1651)
            continue
        elif title[:36] == 'Essay Concerning Human Understanding' and author == 'John Locke':
            year_pub.append(1690)
            continue
        
        elif title[:33] == 'New Essays on Human Understanding' and author == 'Gottfried Wilhelm Leibniz':
            year_pub.append(1705)
            continue
        
        elif author == 'Thomas Reid':
            if title[:34] == 'Essays on the Active Powers of Man':
                year_pub.append(1788)
                continue
                
            elif title[:40] == 'Essays on the Intellectual Powers of Man':
                year_pub.append(1785)
                continue
            else:
                title = title
            
        elif author == 'David Hume' and title[:26] == 'A Treatise of Human Nature':
            year_pub.append(1739)
            continue
        
        elif author == 'Adam Smith' and 'An Inquiry into the Nature and Causes of the Wealth of Nations':
            year_pub.append(1776)
            continue
        
        elif author == 'Immanuel Kant':
            if title == 'The Critique of Pure Reason First Part':
                year_pub.append(1781)
                continue
                
            elif title == 'The Critique of Pure Reason Second Part':
                year_pub.append(1787)
                continue
            else:
                title = title
            
        elif author == 'John Stuart Mill':
            if title[:17] == 'A System of Logic':
                year_pub.append(1843)
                continue
            elif title == 'Liberty' or title == 'Utilitarianism' or title == 'The Subjection of Women':
                title = title
            else:
                year_pub.append(1873)
                continue
                
        for long_title in long_titles:
            if title in long_title:
                components = re.split(r'[(),]', long_title)
                for component in components:
                    year = filter(str.isdigit, component)
                    if len(year) >= 3:
                        year_pub.append(int(year[:4]))
                        break

    base_pdf_link = 'http://www.earlymoderntexts.com'

    links = [unidecode(x['href']) for x in soup.select('li a')][5:]
    first_pdf = links[0].split('/')[-1]

    pdf_links = [base_pdf_link + links[0]]
    filepaths = [os.path.expanduser('~') + '/philosophy_capstone/pdfs/' + first_pdf]

    last_doc = links[0]
    for link in links[1:]:
        if last_doc[:-4] in link:
            continue
        else:
            text_link = base_pdf_link + link
            pdf_name = link.split('/')[-1]
            filepaths.append(os.path.expanduser('~') + '/philosophy_capstone/pdfs/' + pdf_name)
            pdf_links.append(text_link)
            last_doc = link
    
    return text_author, titles, year_pub, pdf_links, filepaths

# %%
documents
# Out:
# defaultdict(dict, {})

# %% [markdown]
# ### Add Documents to Document Dictionary

# %%
for author in authors:
    print('\nReceiving PDF\'s for {}'.format(author))
    text_author, titles, year_pub, pdf_links, filepaths = get_pdfs(author)

    for i in range(len(pdf_links)):
        print('Downloading PDF {} for {}'.format(i, author))
#         urllib.urlretrieve(pdf_links[i], filepaths[i])
#         print('Adding Document')
        documents = add_document(documents, text_author, titles[i], year_pub[i], pdf_links[i], filepaths[i])
#         time.sleep(5)
# Out:
# Receiving PDF's for Niccolo Machiavelli
# Adding Document
#
# Receiving PDF's for Francis Bacon
# Adding Document
#
# Receiving PDF's for Thomas Hobbes
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Rene Descartes
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Robert Boyle
# Adding Document
# Adding Document
#
# Receiving PDF's for Anne Conway
# Adding Document
#
# Receiving PDF's for Baruch Spinoza
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for John Locke
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Nicolas Malebranche
# Adding Document
#
# Receiving PDF's for Gottfried Wilhelm Leibniz
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Anthony Ashley Cooper
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Samuel Clarke
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for George Berkeley
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Joseph Butler
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Francis Hutcheson
# Adding Document
# Adding Document
#
# Receiving PDF's for Jonathan Edwards
# Adding Document
# Adding Document
#
# Receiving PDF's for Julien Offray de La Mettrie
# Adding Document
#
# Receiving PDF's for Thomas Reid
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for David Hume
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Jean-Jacques Rousseau
# Adding Document
#
# Receiving PDF's for Adam Smith
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Richard Price
# Adding Document
#
# Receiving PDF's for Immanuel Kant
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Moses Mendelssohn
# Adding Document
#
# Receiving PDF's for Edmund Burke
# Adding Document
#
# Receiving PDF's for Nicolas de Condorcet
# Adding Document
#
# Receiving PDF's for Jeremy Bentham
# Adding Document
#
# Receiving PDF's for Mary Wollstonecraft
# Adding Document
#
# Receiving PDF's for Benjamin Constant
# Adding Document
#
# Receiving PDF's for John Stuart Mill
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
# Adding Document
#
# Receiving PDF's for Henry Sidgwick
# Adding Document

# %%
documents
# Out:
# defaultdict(dict,
#             {0: {'author': 'Niccolo Machiavelli',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/machiavelli1532.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/machiavelli1532.pdf',
#               'title': 'The Prince',
#               'year': 1532},
#              1: {'author': 'Francis Bacon',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/bacon1620.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/bacon1620.pdf',
#               'title': 'The New Organon',
#               'year': 1620},
#              2: {'author': 'Thomas Hobbes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hobbes1651part1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hobbes1651part1.pdf',
#               'title': 'Leviathan Part 1',
#               'year': 1651},
#              3: {'author': 'Thomas Hobbes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hobbes1651part2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hobbes1651part2.pdf',
#               'title': 'Leviathan Part 2',
#               'year': 1651},
#              4: {'author': 'Thomas Hobbes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hobbes1651part3.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hobbes1651part3.pdf',
#               'title': 'Leviathan Part 3',
#               'year': 1651},
#              5: {'author': 'Thomas Hobbes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hobbes1651part4.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hobbes1651part4.pdf',
#               'title': 'Leviathan Part 4',
#               'year': 1651},
#              6: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1619.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1619.pdf',
#               'title': 'Selected Correspondence',
#               'year': 1619},
#              7: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1637.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1637.pdf',
#               'title': 'Discourse on the Method',
#               'year': 1637},
#              8: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1641.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1641.pdf',
#               'title': 'Meditations on First Philosophy',
#               'year': 1641},
#              9: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1642.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1642.pdf',
#               'title': "Objections to the Meditations, and Descartes' Replies",
#               'year': 1642},
#              10: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1643.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1643.pdf',
#               'title': 'Correspondence with Princess Elisabeth',
#               'year': 1643},
#              11: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1644.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1644.pdf',
#               'title': 'Principles of Philosophy',
#               'year': 1644},
#              12: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1648.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1648.pdf',
#               'title': 'Conversation with Burman',
#               'year': 1648},
#              13: {'author': 'Rene Descartes',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/descartes1649.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/descartes1649.pdf',
#               'title': 'Passions of the Soul',
#               'year': 1649},
#              14: {'author': 'Robert Boyle',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/boyle1666.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/boyle1666.pdf',
#               'title': 'The Origin of Forms and Qualities, Part 1',
#               'year': 1666},
#              15: {'author': 'Robert Boyle',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/boyle1674.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/boyle1674.pdf',
#               'title': 'The Grounds for and Excellence of the Corpuscular or Mechanical Philosophy',
#               'year': 1674},
#              16: {'author': 'Anne Conway',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/conway1692.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/conway1692.pdf',
#               'title': 'The Principles of the Most Ancient and Modern Philosophy',
#               'year': 1692},
#              17: {'author': 'Baruch Spinoza',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/spinoza1661.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/spinoza1661.pdf',
#               'title': 'Correspondence',
#               'year': 1661},
#              18: {'author': 'Baruch Spinoza',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/spinoza1665.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/spinoza1665.pdf',
#               'title': 'Ethics Demonstrated in Geometrical Order',
#               'year': 1665},
#              19: {'author': 'Baruch Spinoza',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/spinoza1669.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/spinoza1669.pdf',
#               'title': 'Treatise on Theology and Politics',
#               'year': 1669},
#              20: {'author': 'John Locke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/locke1689a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/locke1689a.pdf',
#               'title': 'Second Treatise of Government',
#               'year': 1689},
#              21: {'author': 'John Locke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/locke1689b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/locke1689b.pdf',
#               'title': 'Toleration',
#               'year': 1689},
#              22: {'author': 'John Locke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/locke1690book1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/locke1690book1.pdf',
#               'title': 'Essay Concerning Human Understanding Part 1',
#               'year': 1690},
#              23: {'author': 'John Locke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/locke1690book2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/locke1690book2.pdf',
#               'title': 'Essay Concerning Human Understanding Part 2',
#               'year': 1690},
#              24: {'author': 'John Locke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/locke1690book3.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/locke1690book3.pdf',
#               'title': 'Essay Concerning Human Understanding Part 3',
#               'year': 1690},
#              25: {'author': 'John Locke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/locke1690book4.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/locke1690book4.pdf',
#               'title': 'Essay Concerning Human Understanding Part 4',
#               'year': 1690},
#              26: {'author': 'John Locke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/locke1706.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/locke1706.pdf',
#               'title': 'The Conduct of the Understanding',
#               'year': 1706},
#              27: {'author': 'Nicolas Malebranche',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/malebranche1688.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/malebranche1688.pdf',
#               'title': 'Dialogues on Metaphysics',
#               'year': 1688},
#              28: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1680.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1680.pdf',
#               'title': 'Freedom and Possibility',
#               'year': 1680},
#              29: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1684.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1684.pdf',
#               'title': 'Meditations on Knowledge, Truth, and Ideas',
#               'year': 1684},
#              30: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1686a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1686a.pdf',
#               'title': "Leibniz's Correspondence with Arnauld",
#               'year': 1686},
#              31: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1686b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1686b.pdf',
#               'title': 'Contingency',
#               'year': 1686},
#              32: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1686c.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1686c.pdf',
#               'title': 'First Truths',
#               'year': 1686},
#              33: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1686d.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1686d.pdf',
#               'title': 'Discourse on Metaphysics',
#               'year': 1686},
#              34: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1695a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1695a.pdf',
#               'title': 'Real-Life Dialogue on Human Freedom and the Origin of Evil',
#               'year': 1695},
#              35: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1695b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1695b.pdf',
#               'title': 'Essay on Dynamics',
#               'year': 1695},
#              36: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1695c.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1695c.pdf',
#               'title': 'A New System',
#               'year': 1695},
#              37: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1697a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1697a.pdf',
#               'title': "Leibniz's Exchange of Views with Pierre Bayle",
#               'year': 1697},
#              38: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1697b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1697b.pdf',
#               'title': 'The Ultimate Origin on Things',
#               'year': 1697},
#              39: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1698.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1698.pdf',
#               'title': 'Nature Itself',
#               'year': 1698},
#              40: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1705book1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1705book1.pdf',
#               'title': 'New Essays on Human Understanding Book 1',
#               'year': 1705},
#              41: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1705book2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1705book2.pdf',
#               'title': 'New Essays on Human Understanding Book 2',
#               'year': 1705},
#              42: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1705book3.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1705book3.pdf',
#               'title': 'New Essays on Human Understanding Book 3',
#               'year': 1705},
#              43: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1705book4.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1705book4.pdf',
#               'title': 'New Essays on Human Understanding Book 4',
#               'year': 1705},
#              44: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1710.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1710.pdf',
#               'title': 'Making the Case for God',
#               'year': 1710},
#              45: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1714a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1714a.pdf',
#               'title': 'Principles of Nature and Grace',
#               'year': 1714},
#              46: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1714b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1714b.pdf',
#               'title': 'Monadology',
#               'year': 1714},
#              47: {'author': 'Gottfried Wilhelm Leibniz',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1715.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1715.pdf',
#               'title': "Leibniz's Exchange of Papers with Clarke",
#               'year': 1715},
#              48: {'author': 'Anthony Ashley Cooper',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/shaftesbury1708.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/shaftesbury1708.pdf',
#               'title': 'Enthusiasm',
#               'year': 1708},
#              49: {'author': 'Anthony Ashley Cooper',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/shaftesbury1709a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/shaftesbury1709a.pdf',
#               'title': 'The Freedom of Wit and Humour',
#               'year': 1709},
#              50: {'author': 'Anthony Ashley Cooper',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/shaftesbury1709b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/shaftesbury1709b.pdf',
#               'title': 'The Moralists',
#               'year': 1709},
#              51: {'author': 'Anthony Ashley Cooper',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/shaftesbury1710.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/shaftesbury1710.pdf',
#               'title': 'Soliloquy: Advice to an Author',
#               'year': 1710},
#              52: {'author': 'Anthony Ashley Cooper',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/shaftesbury1711.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/shaftesbury1711.pdf',
#               'title': 'An Inquiry Concerning Virtue or Merit',
#               'year': 1711},
#              53: {'author': 'Samuel Clarke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/clarke1704.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/clarke1704.pdf',
#               'title': 'Demonstration of the Being and Attributes of God',
#               'year': 1704},
#              54: {'author': 'Samuel Clarke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/clarke1713.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/clarke1713.pdf',
#               'title': 'Exchange of Letters with Joseph Butler',
#               'year': 1713},
#              55: {'author': 'Samuel Clarke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/leibniz1715.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/leibniz1715.pdf',
#               'title': 'Exchange of Papers with Leibniz',
#               'year': 1715},
#              56: {'author': 'George Berkeley',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/berkeley1709.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/berkeley1709.pdf',
#               'title': 'Essay Towards a New Theory of Vision',
#               'year': 1709},
#              57: {'author': 'George Berkeley',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/berkeley1710.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/berkeley1710.pdf',
#               'title': 'The Principles of Human Knowledge',
#               'year': 1710},
#              58: {'author': 'George Berkeley',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/berkeley1713.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/berkeley1713.pdf',
#               'title': 'Three Dialogues between Hylas and Philonous',
#               'year': 1713},
#              59: {'author': 'George Berkeley',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/berkeley1732.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/berkeley1732.pdf',
#               'title': 'Alciphron',
#               'year': 1732},
#              60: {'author': 'Joseph Butler',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/clarke1713.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/clarke1713.pdf',
#               'title': 'Exchange of Letters with Samuel Clarke',
#               'year': 1713},
#              61: {'author': 'Joseph Butler',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/butler1726.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/butler1726.pdf',
#               'title': 'Preface and Five Sermons from Fifteen Sermons',
#               'year': 1726},
#              62: {'author': 'Joseph Butler',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/butler1736.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/butler1736.pdf',
#               'title': 'Three Episodes from the Analogy of Religion',
#               'year': 1736},
#              63: {'author': 'Francis Hutcheson',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hutcheson1725a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hutcheson1725a.pdf',
#               'title': 'An Inquiry Concerning Beauty, Order, Harmony, and Design',
#               'year': 1725},
#              64: {'author': 'Francis Hutcheson',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hutcheson1725b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hutcheson1725b.pdf',
#               'title': 'An Inquiry Concerning Virtue and Morality',
#               'year': 1725},
#              65: {'author': 'Jonathan Edwards',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/edwards1754.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/edwards1754.pdf',
#               'title': 'The Freedom of the Will',
#               'year': 1754},
#              66: {'author': 'Jonathan Edwards',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/edwards1765.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/edwards1765.pdf',
#               'title': 'A Dissertation Concerning the Nature of True Virtue',
#               'year': 1765},
#              67: {'author': 'Julien Offray de La Mettrie',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/lamettrie1748.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/lamettrie1748.pdf',
#               'title': 'Man--Machine',
#               'year': 1748},
#              68: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1764.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1764.pdf',
#               'title': 'An Inquiry into the Human Mind',
#               'year': 1764},
#              69: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1785essay1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1785essay1.pdf',
#               'title': 'Essays on the Intellectual Powers of Man Essay 1',
#               'year': 1785},
#              70: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1785essay2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1785essay2.pdf',
#               'title': 'Essays on the Intellectual Powers of Man Essay 2',
#               'year': 1785},
#              71: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1785essay3.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1785essay3.pdf',
#               'title': 'Essays on the Intellectual Powers of Man Essay 3',
#               'year': 1785},
#              72: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1785essay4.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1785essay4.pdf',
#               'title': 'Essays on the Intellectual Powers of Man Essay 4',
#               'year': 1785},
#              73: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1785essay5.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1785essay5.pdf',
#               'title': 'Essays on the Intellectual Powers of Man Essay 5',
#               'year': 1785},
#              74: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1785essay6.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1785essay6.pdf',
#               'title': 'Essays on the Intellectual Powers of Man Essay 6',
#               'year': 1785},
#              75: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1785essay7.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1785essay7.pdf',
#               'title': 'Essays on the Intellectual Powers of Man Essay 7',
#               'year': 1785},
#              76: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1788essay1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1788essay1.pdf',
#               'title': 'Essays on the Active Powers of Man Essay 1',
#               'year': 1788},
#              77: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1788essay2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1788essay2.pdf',
#               'title': 'Essays on the Active Powers of Man Essay 2',
#               'year': 1788},
#              78: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1788essay3.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1788essay3.pdf',
#               'title': 'Essays on the Active Powers of Man Essay 3',
#               'year': 1788},
#              79: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1788essay4.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1788essay4.pdf',
#               'title': 'Essays on the Active Powers of Man Essay 4',
#               'year': 1788},
#              80: {'author': 'Thomas Reid',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/reid1788essay5.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/reid1788essay5.pdf',
#               'title': 'Essays on the Active Powers of Man Essay 5',
#               'year': 1788},
#              81: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1739book1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1739book1.pdf',
#               'title': 'A Treatise of Human Nature Book I',
#               'year': 1739},
#              82: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1739book2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1739book2.pdf',
#               'title': 'A Treatise of Human Nature Book II',
#               'year': 1739},
#              83: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1740book3.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1740book3.pdf',
#               'title': 'A Treatise of Human Nature Book III',
#               'year': 1739},
#              84: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1740.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1740.pdf',
#               'title': 'Abstract of the Treatise of Human Nature',
#               'year': 1740},
#              85: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1748.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1748.pdf',
#               'title': 'An Enquiry Concerning Human Understanding',
#               'year': 1748},
#              86: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1751.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1751.pdf',
#               'title': 'An Enquiry Concerning the Principles of Morals',
#               'year': 1751},
#              87: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1757.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1757.pdf',
#               'title': 'Four Essays',
#               'year': 1757},
#              88: {'author': 'David Hume',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/hume1779.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/hume1779.pdf',
#               'title': 'Dialogues Concerning Natural Religion',
#               'year': 1779},
#              89: {'author': 'Jean-Jacques Rousseau',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/rousseau1762.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/rousseau1762.pdf',
#               'title': 'The Social Contract',
#               'year': 1762},
#              90: {'author': 'Adam Smith',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/smith1759.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/smith1759.pdf',
#               'title': 'The Theory of Moral Sentiments',
#               'year': 1776},
#              91: {'author': 'Adam Smith',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/smith1776_1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/smith1776_1.pdf',
#               'title': 'An Inquiry into the Nature and Causes of the Wealth of Nations Book I',
#               'year': 1776},
#              92: {'author': 'Adam Smith',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/smith1776_2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/smith1776_2.pdf',
#               'title': 'An Inquiry into the Nature and Causes of the Wealth of Nations Book II',
#               'year': 1776},
#              93: {'author': 'Adam Smith',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/smith1776_34.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/smith1776_34.pdf',
#               'title': 'An Inquiry into the Nature and Causes of the Wealth of Nations Books III and IV',
#               'year': 1776},
#              94: {'author': 'Adam Smith',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/smith1776_5.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/smith1776_5.pdf',
#               'title': 'An Inquiry into the Nature and Causes of the Wealth of Nations Book V',
#               'year': 1776},
#              95: {'author': 'Richard Price',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/price1758.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/price1758.pdf',
#               'title': 'A Review of the Principle Questions in Morals',
#               'year': 1758},
#              96: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1770.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1770.pdf',
#               'title': 'The Form and Principles of the Sensible and Intelligible World',
#               'year': 1770},
#              97: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1781part1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1781part1.pdf',
#               'title': 'The Critique of Pure Reason First Part',
#               'year': 1781},
#              98: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1781part2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1781part2.pdf',
#               'title': 'The Critique of Pure Reason Second Part',
#               'year': 1787},
#              99: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1783.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1783.pdf',
#               'title': 'Prolegomena to any Future Metaphysic',
#               'year': 1783},
#              100: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1785.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1785.pdf',
#               'title': 'Groundwork for the Metaphysic of Morals',
#               'year': 1785},
#              101: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1786.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1786.pdf',
#               'title': 'Metaphysical Foundations of Natural Science',
#               'year': 1786},
#              102: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1793.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1793.pdf',
#               'title': 'Religion Within the Bounds of Bare Reason',
#               'year': 1793},
#              103: {'author': 'Immanuel Kant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/kant1795.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/kant1795.pdf',
#               'title': 'Toward Perpetual Peace',
#               'year': 1795},
#              104: {'author': 'Moses Mendelssohn',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mendelssohn1782.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mendelssohn1782.pdf',
#               'title': 'Jerusalem: or Religious Power and Judaism',
#               'year': 1782},
#              105: {'author': 'Edmund Burke',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/burke1790.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/burke1790.pdf',
#               'title': 'Reflections on the Revolution in France',
#               'year': 1790},
#              106: {'author': 'Nicolas de Condorcet',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/condorcet1795.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/condorcet1795.pdf',
#               'title': 'Sketch for an Historical Picture of the Advances of the Human Mind',
#               'year': 1795},
#              107: {'author': 'Jeremy Bentham',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/bentham1780.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/bentham1780.pdf',
#               'title': 'An Introduction to the Principles of Morals and Legislation',
#               'year': 1780},
#              108: {'author': 'Mary Wollstonecraft',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/wollstonecraft1792.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/wollstonecraft1792.pdf',
#               'title': 'A Vindication of the Rights of Woman',
#               'year': 1792},
#              109: {'author': 'Benjamin Constant',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/constant1819.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/constant1819.pdf',
#               'title': 'The Liberty of the Ancients Compared with that of the Moderns',
#               'year': 1819},
#              110: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1843book1.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1843book1.pdf',
#               'title': 'A System of Logic Book I',
#               'year': 1843},
#              111: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1843book2.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1843book2.pdf',
#               'title': 'A System of Logic Book II',
#               'year': 1843},
#              112: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1843book3.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1843book3.pdf',
#               'title': 'A System of Logic Book III',
#               'year': 1843},
#              113: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1843book4.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1843book4.pdf',
#               'title': 'A System of Logic Book IV',
#               'year': 1843},
#              114: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1859.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1859.pdf',
#               'title': 'Liberty',
#               'year': 1859},
#              115: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1863.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1863.pdf',
#               'title': 'Utilitarianism',
#               'year': 1863},
#              116: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1869.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1869.pdf',
#               'title': 'The Subjection of Women',
#               'year': 1869},
#              117: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1873a.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1873a.pdf',
#               'title': "Helen Taylor's Introduction to the Essays",
#               'year': 1873},
#              118: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1873b.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1873b.pdf',
#               'title': 'Nature',
#               'year': 1873},
#              119: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1873c.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1873c.pdf',
#               'title': 'The Usefulness of Religion',
#               'year': 1873},
#              120: {'author': 'John Stuart Mill',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/mill1873d.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/mill1873d.pdf',
#               'title': 'Theism',
#               'year': 1873},
#              121: {'author': 'Henry Sidgwick',
#               'pdf_file': '/Users/tylerlazoen/philosophy_capstone/pdfs/sidgwick1874.pdf',
#               'pdf_url': 'http://www.earlymoderntexts.com/assets/pdfs/sidgwick1874.pdf',
#               'title': 'The Methods of Ethics',
#               'year': 1874}})

# %% [markdown]
# ### PDF Text Extraction Functions

# %%
from cStringIO import StringIO
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument

# %%
def convert(fname, pages=None):
    if not pages:
        pagenums = set()
    else:
        pagenums = set(pages)

    output = StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    infile = file(fname, 'rb')
    for page in PDFPage.get_pages(infile, pagenums):
        interpreter.process_page(page)
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close
    return text

# %%
def get_text(pdf_file, author):
    text = convert(pdf_file)
    
    start = text.find('Copyright')
    end = text[start:].find(author) + len(text[:start])
    
    if not (start == -1 or end == -1):
        text = text[:start] + text[end-1:]
        name_first = text.find(author)
        idx = name_first + len(author)
        text = text[:idx] + text[idx:].replace(author, '')
    
    text = text.strip(punctuation)
    
    if not(text.isalpha()):
        text_lst = text.split()
        
        for i in range(len(text_lst)):
            if not(text_lst[i].isalpha()):
                text_lst[i] = filter(str.isalnum, text_lst[i])
        
        text = ' '.join(word for word in text_lst)
    
    return text

# %% [markdown]
# ### Make Documents Dictionary Pandas Dataframe and Add Text

# %%
import pandas as pd
lst = []
for key in documents.keys():
    lst.append(documents[key])

# %%
documents_df = pd.DataFrame(lst)

# %%
import numpy as np
documents_df['text'] = np.nan
documents_df.head()
# Out:
#                 author                                           pdf_file  \
# 0  Niccolo Machiavelli  /Users/tylerlazoen/philosophy_capstone/pdfs/ma...
# 1        Francis Bacon  /Users/tylerlazoen/philosophy_capstone/pdfs/ba...
# 2        Thomas Hobbes  /Users/tylerlazoen/philosophy_capstone/pdfs/ho...
# 3        Thomas Hobbes  /Users/tylerlazoen/philosophy_capstone/pdfs/ho...
# 4        Thomas Hobbes  /Users/tylerlazoen/philosophy_capstone/pdfs/ho...
#
#                                              pdf_url             title  year  \
# 0  http://www.earlymoderntexts.com/assets/pdfs/ma...        The Prince  1532
# 1  http://www.earlymoderntexts.com/assets/pdfs/ba...   The New Organon  1620
# 2  http://www.earlymoderntexts.com/assets/pdfs/ho...  Leviathan Part 1  1651
# 3  http://www.earlymoderntexts.com/assets/pdfs/ho...  Leviathan Part 2  1651
# 4  http://www.earlymoderntexts.com/assets/pdfs/ho...  Leviathan Part 3  1651
#
#    text
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
for i in range(documents_df.shape[0]):
    author = documents_df.loc[i, 'author']
    pdf_file = documents_df.loc[i, 'pdf_file']
    print('\nGetting Text for {}'.format(documents_df.loc[i, 'title']))
    documents_df.loc[i, 'text'] = get_text(pdf_file, author)
# Out:
# Getting Text for The Prince
#
# Getting Text for The New Organon
#
# Getting Text for Leviathan Part 1
#
# Getting Text for Leviathan Part 2
#
# Getting Text for Leviathan Part 3
#
# Getting Text for Leviathan Part 4
#
# Getting Text for Selected Correspondence
#
# Getting Text for Discourse on the Method
#
# Getting Text for Meditations on First Philosophy
#
# Getting Text for Objections to the Meditations, and Descartes' Replies
#
# Getting Text for Correspondence with Princess Elisabeth
#
# Getting Text for Principles of Philosophy
#
# Getting Text for Conversation with Burman
#
# Getting Text for Passions of the Soul
#
# Getting Text for The Origin of Forms and Qualities, Part 1
#
# Getting Text for The Grounds for and Excellence of the Corpuscular or Mechanical Philosophy
#
# Getting Text for The Principles of the Most Ancient and Modern Philosophy
#
# Getting Text for Correspondence
#
# Getting Text for Ethics Demonstrated in Geometrical Order
#
# Getting Text for Treatise on Theology and Politics
#
# Getting Text for Second Treatise of Government
#
# Getting Text for Toleration
#
# Getting Text for Essay Concerning Human Understanding Part 1
#
# Getting Text for Essay Concerning Human Understanding Part 2
#
# Getting Text for Essay Concerning Human Understanding Part 3
#
# Getting Text for Essay Concerning Human Understanding Part 4
#
# Getting Text for The Conduct of the Understanding
#
# Getting Text for Dialogues on Metaphysics
#
# Getting Text for Freedom and Possibility
#
# Getting Text for Meditations on Knowledge, Truth, and Ideas
#
# Getting Text for Leibniz's Correspondence with Arnauld
#
# Getting Text for Contingency
#
# Getting Text for First Truths
#
# Getting Text for Discourse on Metaphysics
#
# Getting Text for Real-Life Dialogue on Human Freedom and the Origin of Evil
#
# Getting Text for Essay on Dynamics
#
# Getting Text for A New System
#
# Getting Text for Leibniz's Exchange of Views with Pierre Bayle
#
# Getting Text for The Ultimate Origin on Things
#
# Getting Text for Nature Itself
#
# Getting Text for New Essays on Human Understanding Book 1
#
# Getting Text for New Essays on Human Understanding Book 2
#
# Getting Text for New Essays on Human Understanding Book 3
#
# Getting Text for New Essays on Human Understanding Book 4
#
# Getting Text for Making the Case for God
#
# Getting Text for Principles of Nature and Grace
#
# Getting Text for Monadology
#
# Getting Text for Leibniz's Exchange of Papers with Clarke
#
# Getting Text for Enthusiasm
#
# Getting Text for The Freedom of Wit and Humour
#
# Getting Text for The Moralists
#
# Getting Text for Soliloquy: Advice to an Author
#
# Getting Text for An Inquiry Concerning Virtue or Merit
#
# Getting Text for Demonstration of the Being and Attributes of God
#
# Getting Text for Exchange of Letters with Joseph Butler
#
# Getting Text for Exchange of Papers with Leibniz
#
# Getting Text for Essay Towards a New Theory of Vision
#
# Getting Text for The Principles of Human Knowledge
#
# Getting Text for Three Dialogues between Hylas and Philonous
#
# Getting Text for Alciphron
#
# Getting Text for Exchange of Letters with Samuel Clarke
#
# Getting Text for Preface and Five Sermons from Fifteen Sermons
#
# Getting Text for Three Episodes from the Analogy of Religion
#
# Getting Text for An Inquiry Concerning Beauty, Order, Harmony, and Design
#
# Getting Text for An Inquiry Concerning Virtue and Morality
#
# Getting Text for The Freedom of the Will
#
# Getting Text for A Dissertation Concerning the Nature of True Virtue
#
# Getting Text for Man--Machine
#
# Getting Text for An Inquiry into the Human Mind
#
# Getting Text for Essays on the Intellectual Powers of Man Essay 1
#
# Getting Text for Essays on the Intellectual Powers of Man Essay 2
#
# Getting Text for Essays on the Intellectual Powers of Man Essay 3
#
# Getting Text for Essays on the Intellectual Powers of Man Essay 4
#
# Getting Text for Essays on the Intellectual Powers of Man Essay 5
#
# Getting Text for Essays on the Intellectual Powers of Man Essay 6
#
# Getting Text for Essays on the Intellectual Powers of Man Essay 7
#
# Getting Text for Essays on the Active Powers of Man Essay 1
#
# Getting Text for Essays on the Active Powers of Man Essay 2
#
# Getting Text for Essays on the Active Powers of Man Essay 3
#
# Getting Text for Essays on the Active Powers of Man Essay 4
#
# Getting Text for Essays on the Active Powers of Man Essay 5
#
# Getting Text for A Treatise of Human Nature Book I
#
# Getting Text for A Treatise of Human Nature Book II
#
# Getting Text for A Treatise of Human Nature Book III
#
# Getting Text for Abstract of the Treatise of Human Nature
#
# Getting Text for An Enquiry Concerning Human Understanding
#
# Getting Text for An Enquiry Concerning the Principles of Morals
#
# Getting Text for Four Essays
#
# Getting Text for Dialogues Concerning Natural Religion
#
# Getting Text for The Social Contract
#
# Getting Text for The Theory of Moral Sentiments
#
# Getting Text for An Inquiry into the Nature and Causes of the Wealth of Nations Book I
#
# Getting Text for An Inquiry into the Nature and Causes of the Wealth of Nations Book II
#
# Getting Text for An Inquiry into the Nature and Causes of the Wealth of Nations Books III and IV
#
# Getting Text for An Inquiry into the Nature and Causes of the Wealth of Nations Book V
#
# Getting Text for A Review of the Principle Questions in Morals
#
# Getting Text for The Form and Principles of the Sensible and Intelligible World
#
# Getting Text for The Critique of Pure Reason First Part
#
# Getting Text for The Critique of Pure Reason Second Part
#
# Getting Text for Prolegomena to any Future Metaphysic
#
# Getting Text for Groundwork for the Metaphysic of Morals
#
# Getting Text for Metaphysical Foundations of Natural Science
#
# Getting Text for Religion Within the Bounds of Bare Reason
#
# Getting Text for Toward Perpetual Peace
#
# Getting Text for Jerusalem: or Religious Power and Judaism
#
# Getting Text for Reflections on the Revolution in France
#
# Getting Text for Sketch for an Historical Picture of the Advances of the Human Mind
#
# Getting Text for An Introduction to the Principles of Morals and Legislation
#
# Getting Text for A Vindication of the Rights of Woman
#
# Getting Text for The Liberty of the Ancients Compared with that of the Moderns
#
# Getting Text for A System of Logic Book I
#
# Getting Text for A System of Logic Book II
#
# Getting Text for A System of Logic Book III
#
# Getting Text for A System of Logic Book IV
#
# Getting Text for Liberty
#
# Getting Text for Utilitarianism
#
# Getting Text for The Subjection of Women
#
# Getting Text for Helen Taylor's Introduction to the Essays
#
# Getting Text for Nature
#
# Getting Text for The Usefulness of Religion
#
# Getting Text for Theism
#
# Getting Text for The Methods of Ethics

# %%
documents_df = pd.read_csv('data/documents.csv')
cols = list(documents_df)
cols.insert(0, cols.pop(cols.index('title')))
cols.insert(1, cols.pop(cols.index('author')))
cols.insert(2, cols.pop(cols.index('year')))
cols.insert(3, cols.pop(cols.index('text')))
# cols.pop(cols.index('pdf_url'))
cols.insert(4, cols.pop(cols.index('url')))
cols.append('filepath')
cols.pop(cols.index('pdf_file'))
cols = [x.lower() for x in cols]
documents_df = documents_df.ix[:, cols]
documents_df['url'] = [x['pdf_url'] for x in lst]
documents_df['filepath'] = [x['pdf_file'] for x in lst]
documents_df.drop('unnamed: 0', axis=1, inplace=True)
documents_df.head()
# Out:
#               title               author  year  \
# 0        The Prince  Niccolo Machiavelli  1532
# 1   The New Organon        Francis Bacon  1620
# 2  Leviathan Part 1        Thomas Hobbes  1651
# 3  Leviathan Part 2        Thomas Hobbes  1651
# 4  Leviathan Part 3        Thomas Hobbes  1651
#
#                                                 text  \
# 0  The Prince Niccol Machiavelli Copyright 201020...
# 1  or True Directions Concerning the Interpretati...
# 2  Leviathan Part 1 Man Thomas Hobbes Chapter 3 T...
# 3  Leviathan Part 2 Commonwealth Thomas Hobbes Ch...
# 4  Leviathan Part 3 A Christian Commonwealth Thom...
#
#                                                  url  \
# 0  http://www.earlymoderntexts.com/assets/pdfs/ma...
# 1  http://www.earlymoderntexts.com/assets/pdfs/ba...
# 2  http://www.earlymoderntexts.com/assets/pdfs/ho...
# 3  http://www.earlymoderntexts.com/assets/pdfs/ho...
# 4  http://www.earlymoderntexts.com/assets/pdfs/ho...
#
#                                             filepath
# 0  /Users/tylerlazoen/philosophy_capstone/pdfs/ma...
# 1  /Users/tylerlazoen/philosophy_capstone/pdfs/ba...
# 2  /Users/tylerlazoen/philosophy_capstone/pdfs/ho...
# 3  /Users/tylerlazoen/philosophy_capstone/pdfs/ho...
# 4  /Users/tylerlazoen/philosophy_capstone/pdfs/ho...

# %% [markdown]
# ### Make Philosophers Dictionary a Pandas Dataframe

# %%
philosophers
# Out:
# DefaultOrderedDict([('Thales of Miletos',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thales_of_miletos.jpg',
#                       'name': 'Thales of Miletos',
#                       'time_period': 'presocratic',
#                       'year_born': -624,
#                       'year_died': -546}),
#                     ('Anaximander',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anaximander.jpg',
#                       'name': 'Anaximander',
#                       'time_period': 'presocratic',
#                       'year_born': -610,
#                       'year_died': -546}),
#                     ('Anaximenes',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anaximenes.jpg',
#                       'name': 'Anaximenes',
#                       'time_period': 'presocratic',
#                       'year_born': -585,
#                       'year_died': -525}),
#                     ('Pythagoras',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/pythagoras.jpg',
#                       'name': 'Pythagoras',
#                       'time_period': 'presocratic',
#                       'year_born': -570,
#                       'year_died': -490}),
#                     ('Heraclitus',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/heraclitus.jpg',
#                       'name': 'Heraclitus',
#                       'time_period': 'presocratic',
#                       'year_born': -535,
#                       'year_died': -475}),
#                     ('Parmenides of Elea',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/parmenides_of_elea.jpg',
#                       'name': 'Parmenides of Elea',
#                       'time_period': 'presocratic',
#                       'year_born': -515,
#                       'year_died': -450}),
#                     ('Anaxagoras',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anaxagoras.jpg',
#                       'name': 'Anaxagoras',
#                       'time_period': 'presocratic',
#                       'year_born': -500,
#                       'year_died': -428}),
#                     ('Empedocles',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/empedocles.jpg',
#                       'name': 'Empedocles',
#                       'time_period': 'presocratic',
#                       'year_born': -490,
#                       'year_died': -430}),
#                     ('Zeno of Elea',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/zeno_of_elea.jpg',
#                       'name': 'Zeno of Elea',
#                       'time_period': 'presocratic',
#                       'year_born': -490,
#                       'year_died': -430}),
#                     ('Protagoras',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/protagoras.jpg',
#                       'name': 'Protagoras',
#                       'time_period': 'presocratic',
#                       'year_born': -490,
#                       'year_died': -420}),
#                     ('Gorgias',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gorgias.jpg',
#                       'name': 'Gorgias',
#                       'time_period': 'presocratic',
#                       'year_born': -487,
#                       'year_died': -376}),
#                     ('Democritus',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/democritus.jpg',
#                       'name': 'Democritus',
#                       'time_period': 'presocratic',
#                       'year_born': -460,
#                       'year_died': -370}),
#                     ('Socrates',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/socrates.jpg',
#                       'name': 'Socrates',
#                       'time_period': 'socratic',
#                       'year_born': -469,
#                       'year_died': -399}),
#                     ('Plato',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/plato.jpg',
#                       'name': 'Plato',
#                       'time_period': 'socratic',
#                       'year_born': -428,
#                       'year_died': -348}),
#                     ('Diogenes of Sinope',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/diogenes_of_sinope.jpg',
#                       'name': 'Diogenes of Sinope',
#                       'time_period': 'socratic',
#                       'year_born': -412,
#                       'year_died': -323}),
#                     ('Aristotle',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/aristotle.jpg',
#                       'name': 'Aristotle',
#                       'time_period': 'socratic',
#                       'year_born': -384,
#                       'year_died': -322}),
#                     ('Thucydides',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thucydides.jpg',
#                       'name': 'Thucydides',
#                       'time_period': 'socratic',
#                       'year_born': -460,
#                       'year_died': -400}),
#                     ('Pyrrho',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/pyrrho.jpg',
#                       'name': 'Pyrrho',
#                       'time_period': 'hellenistic',
#                       'year_born': -360,
#                       'year_died': -270}),
#                     ('Epicurus',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/epicurus.jpg',
#                       'name': 'Epicurus',
#                       'time_period': 'hellenistic',
#                       'year_born': -341,
#                       'year_died': -270}),
#                     ('Zeno of Citium',
#                      {'Nationality': 'Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/zeno_of_citium.jpg',
#                       'name': 'Zeno of Citium',
#                       'time_period': 'hellenistic',
#                       'year_born': -334,
#                       'year_died': -262}),
#                     ('Philo',
#                      {'Nationality': 'Egyptian-Jewish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/philo.jpg',
#                       'name': 'Philo',
#                       'time_period': 'hellenistic',
#                       'year_born': -20,
#                       'year_died': 50}),
#                     ('Plotinus',
#                      {'Nationality': 'Egyptian-Greek',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/plotinus.jpg',
#                       'name': 'Plotinus',
#                       'time_period': 'hellenistic',
#                       'year_born': 204,
#                       'year_died': 270}),
#                     ('Marcus Tullius Cicero',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/marcus_tullius_cicero.jpg',
#                       'name': 'Marcus Tullius Cicero',
#                       'time_period': 'roman',
#                       'year_born': -106,
#                       'year_died': -43}),
#                     ('Epictetus',
#                      {'Nationality': 'Greek-Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/epictetus.jpg',
#                       'name': 'Epictetus',
#                       'time_period': 'roman',
#                       'year_born': 55,
#                       'year_died': 135}),
#                     ('Marcus Aurelius',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/marcus_aurelius.jpg',
#                       'name': 'Marcus Aurelius',
#                       'time_period': 'roman',
#                       'year_born': 55,
#                       'year_died': 135}),
#                     ('St. Augustine of Hippo',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/st._augustine_of_hippo.jpg',
#                       'name': 'St. Augustine of Hippo',
#                       'time_period': 'roman',
#                       'year_born': 354,
#                       'year_died': 430}),
#                     ('Boethius',
#                      {'Nationality': 'Roman',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/boethius.jpg',
#                       'name': 'Boethius',
#                       'time_period': 'roman',
#                       'year_born': 480,
#                       'year_died': 525}),
#                     ('Avicenna',
#                      {'Nationality': 'Persian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/avicenna.jpg',
#                       'name': 'Avicenna',
#                       'time_period': 'medieval',
#                       'year_born': 980,
#                       'year_died': 1037}),
#                     ('St. Anselm',
#                      {'Nationality': 'Italian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/st._anselm.jpg',
#                       'name': 'St. Anselm',
#                       'time_period': 'medieval',
#                       'year_born': 1033,
#                       'year_died': 1109}),
#                     ('Peter Abelard',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/peter_abelard.jpg',
#                       'name': 'Peter Abelard',
#                       'time_period': 'medieval',
#                       'year_born': 1079,
#                       'year_died': 1142}),
#                     ('Averroes',
#                      {'Nationality': 'Spanish-Arabic',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/averroes.jpg',
#                       'name': 'Averroes',
#                       'time_period': 'medieval',
#                       'year_born': 1126,
#                       'year_died': 1198}),
#                     ('Maimonides',
#                      {'Nationality': 'Spanish-Jewish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/maimonides.jpg',
#                       'name': 'Maimonides',
#                       'time_period': 'medieval',
#                       'year_born': 1135,
#                       'year_died': 1204}),
#                     ('Albertus Magnus',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/albertus_magnus.jpg',
#                       'name': 'Albertus Magnus',
#                       'time_period': 'medieval',
#                       'year_born': 1200,
#                       'year_died': 1280}),
#                     ('Roger Bacon',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/roger_bacon.jpg',
#                       'name': 'Roger Bacon',
#                       'time_period': 'medieval',
#                       'year_born': 1214,
#                       'year_died': 1294}),
#                     ('St. Thomas Aquinas',
#                      {'Nationality': 'Italian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/st._thomas_aquinas.jpg',
#                       'name': 'St. Thomas Aquinas',
#                       'time_period': 'medieval',
#                       'year_born': 1225,
#                       'year_died': 1274}),
#                     ('John Duns Scotus',
#                      {'Nationality': 'Scottish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_duns_scotus.jpg',
#                       'name': 'John Duns Scotus',
#                       'time_period': 'medieval',
#                       'year_born': 1266,
#                       'year_died': 1308}),
#                     ('William of Ockham',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/william_of_ockham.jpg',
#                       'name': 'William of Ockham',
#                       'time_period': 'medieval',
#                       'year_born': 1285,
#                       'year_died': 1348}),
#                     ('Desiderius Erasmus',
#                      {'Nationality': 'Dutch',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/desiderius_erasmus.jpg',
#                       'name': 'Desiderius Erasmus',
#                       'time_period': 'renaissance',
#                       'year_born': 1466,
#                       'year_died': 1536}),
#                     ('Niccolo Machiavelli',
#                      {'Nationality': 'Italian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/niccolo_machiavelli.jpg',
#                       'name': 'Niccolo Machiavelli',
#                       'time_period': 'renaissance',
#                       'year_born': 1469,
#                       'year_died': 1527}),
#                     ('Thomas More',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thomas_more.jpg',
#                       'name': 'Thomas More',
#                       'time_period': 'renaissance',
#                       'year_born': 1478,
#                       'year_died': 1535}),
#                     ('Francis Bacon',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/francis_bacon.jpg',
#                       'name': 'Francis Bacon',
#                       'time_period': 'renaissance',
#                       'year_born': 1561,
#                       'year_died': 1626}),
#                     ('Thomas Hobbes',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thomas_hobbes.jpg',
#                       'name': 'Thomas Hobbes',
#                       'time_period': 'reason',
#                       'year_born': 1588,
#                       'year_died': 1679}),
#                     ('Rene Descartes',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/rene_descartes.jpg',
#                       'name': 'Rene Descartes',
#                       'time_period': 'reason',
#                       'year_born': 1596,
#                       'year_died': 1650}),
#                     ('Blaise Pascal',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/blaise_pascal.jpg',
#                       'name': 'Blaise Pascal',
#                       'time_period': 'reason',
#                       'year_born': 1623,
#                       'year_died': 1662}),
#                     ('Baruch Spinoza',
#                      {'Nationality': 'Dutch-Jewish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/baruch_spinoza.jpg',
#                       'name': 'Baruch Spinoza',
#                       'time_period': 'reason',
#                       'year_born': 1623,
#                       'year_died': 1677}),
#                     ('John Locke',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_locke.jpg',
#                       'name': 'John Locke',
#                       'time_period': 'reason',
#                       'year_born': 1632,
#                       'year_died': 1704}),
#                     ('Nicolas Malebranche',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/nicolas_malebranche.jpg',
#                       'name': 'Nicolas Malebranche',
#                       'time_period': 'reason',
#                       'year_born': 1638,
#                       'year_died': 1715}),
#                     ('Gottfried Wilhelm Leibniz',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gottfried_wilhelm_leibniz.jpg',
#                       'name': 'Gottfried Wilhelm Leibniz',
#                       'time_period': 'reason',
#                       'year_born': 1646,
#                       'year_died': 1716}),
#                     ('Bishop George Berkeley',
#                      {'Nationality': 'Irish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/bishop_george_berkeley.jpg',
#                       'name': 'Bishop George Berkeley',
#                       'time_period': 'enlightenment',
#                       'year_born': 1685,
#                       'year_died': 1753}),
#                     ('Voltaire',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/voltaire.jpg',
#                       'name': 'Voltaire',
#                       'time_period': 'enlightenment',
#                       'year_born': 1694,
#                       'year_died': 1778}),
#                     ('David Hume',
#                      {'Nationality': 'Scottish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/david_hume.jpg',
#                       'name': 'David Hume',
#                       'time_period': 'enlightenment',
#                       'year_born': 1711,
#                       'year_died': 1776}),
#                     ('Jean-Jacques Rousseau',
#                      {'Nationality': 'Swiss-French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jean-jacques_rousseau.jpg',
#                       'name': 'Jean-Jacques Rousseau',
#                       'time_period': 'enlightenment',
#                       'year_born': 1712,
#                       'year_died': 1778}),
#                     ('Adam Smith',
#                      {'Nationality': 'Scottish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/adam_smith.jpg',
#                       'name': 'Adam Smith',
#                       'time_period': 'enlightenment',
#                       'year_born': 1723,
#                       'year_died': 1790}),
#                     ('Immanuel Kant',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/immanuel_kant.jpg',
#                       'name': 'Immanuel Kant',
#                       'time_period': 'enlightenment',
#                       'year_born': 1724,
#                       'year_died': 1804}),
#                     ('Edmund Burke',
#                      {'Nationality': 'Irish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/edmund_burke.jpg',
#                       'name': 'Edmund Burke',
#                       'time_period': 'enlightenment',
#                       'year_born': 1729,
#                       'year_died': 1797}),
#                     ('Jeremy Bentham',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jeremy_bentham.jpg',
#                       'name': 'Jeremy Bentham',
#                       'time_period': 'modern',
#                       'year_born': 1748,
#                       'year_died': 1832}),
#                     ('Johann Gottlieb Fichte',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/johann_gottlieb_fichte.jpg',
#                       'name': 'Johann Gottlieb Fichte',
#                       'time_period': 'modern',
#                       'year_born': 1762,
#                       'year_died': 1814}),
#                     ('G.W.F. Hegel',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/g.w.f._hegel.jpg',
#                       'name': 'G.W.F. Hegel',
#                       'time_period': 'modern',
#                       'year_born': 1770,
#                       'year_died': 1831}),
#                     ('Friedrich Schelling',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/friedrich_schelling.jpg',
#                       'name': 'Friedrich Schelling',
#                       'time_period': 'modern',
#                       'year_born': 1775,
#                       'year_died': 1854}),
#                     ('Arthur Schopenhauer',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/arthur_schopenhauer.jpg',
#                       'name': 'Arthur Schopenhauer',
#                       'time_period': 'modern',
#                       'year_born': 1788,
#                       'year_died': 1860}),
#                     ('Auguste Comte',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/auguste_comte.jpg',
#                       'name': 'Auguste Comte',
#                       'time_period': 'modern',
#                       'year_born': 1798,
#                       'year_died': 1857}),
#                     ('Ralph Waldo Emerson',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/ralph_waldo_emerson.jpg',
#                       'name': 'Ralph Waldo Emerson',
#                       'time_period': 'modern',
#                       'year_born': 1803,
#                       'year_died': 1882}),
#                     ('John Stuart Mill',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_stuart_mill.jpg',
#                       'name': 'John Stuart Mill',
#                       'time_period': 'modern',
#                       'year_born': 1806,
#                       'year_died': 1873}),
#                     ('Soren Kierkegaard',
#                      {'Nationality': 'Danish',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/soren_kierkegaard.jpg',
#                       'name': 'Soren Kierkegaard',
#                       'time_period': 'modern',
#                       'year_born': 1813,
#                       'year_died': 1855}),
#                     ('Henry David Thoreau',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/henry_david_thoreau.jpg',
#                       'name': 'Henry David Thoreau',
#                       'time_period': 'modern',
#                       'year_born': 1817,
#                       'year_died': 1862}),
#                     ('Karl Marx',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/karl_marx.jpg',
#                       'name': 'Karl Marx',
#                       'time_period': 'modern',
#                       'year_born': 1818,
#                       'year_died': 1883}),
#                     ('Charles Sanders Peirce',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/charles_sanders_peirce.jpg',
#                       'name': 'Charles Sanders Peirce',
#                       'time_period': 'modern',
#                       'year_born': 1839,
#                       'year_died': 1914}),
#                     ('William James',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/william_james.jpg',
#                       'name': 'William James',
#                       'time_period': 'modern',
#                       'year_born': 1842,
#                       'year_died': 1910}),
#                     ('Friedrich Nietzsche',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/friedrich_nietzsche.jpg',
#                       'name': 'Friedrich Nietzsche',
#                       'time_period': 'modern',
#                       'year_born': 1844,
#                       'year_died': 1900}),
#                     ('Gottlob Frege',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gottlob_frege.jpg',
#                       'name': 'Gottlob Frege',
#                       'time_period': 'modern',
#                       'year_born': 1848,
#                       'year_died': 1925}),
#                     ('John Dewey',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/john_dewey.jpg',
#                       'name': 'John Dewey',
#                       'time_period': 'modern',
#                       'year_born': 1859,
#                       'year_died': 1952}),
#                     ('Edmund Husserl',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/edmund_husserl.jpg',
#                       'name': 'Edmund Husserl',
#                       'time_period': 'modern',
#                       'year_born': 1859,
#                       'year_died': 1938}),
#                     ('Alfred North Whitehead',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/alfred_north_whitehead.jpg',
#                       'name': 'Alfred North Whitehead',
#                       'time_period': 'modern',
#                       'year_born': 1861,
#                       'year_died': 1947}),
#                     ('Bertrand Russell',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/bertrand_russell.jpg',
#                       'name': 'Bertrand Russell',
#                       'time_period': 'modern',
#                       'year_born': 1872,
#                       'year_died': 1970}),
#                     ('George Edward Moore',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/george_edward_moore.jpg',
#                       'name': 'George Edward Moore',
#                       'time_period': 'modern',
#                       'year_born': 1873,
#                       'year_died': 1958}),
#                     ('Ludwig Wittgenstein',
#                      {'Nationality': 'Austrian',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/ludwig_wittgenstein.jpg',
#                       'name': 'Ludwig Wittgenstein',
#                       'time_period': 'modern',
#                       'year_born': 1889,
#                       'year_died': 1951}),
#                     ('Martin Heidegger',
#                      {'Nationality': 'German',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/martin_heidegger.jpg',
#                       'name': 'Martin Heidegger',
#                       'time_period': 'modern',
#                       'year_born': 1889,
#                       'year_died': 1976}),
#                     ('Gilbert Ryle',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/gilbert_ryle.jpg',
#                       'name': 'Gilbert Ryle',
#                       'time_period': 'modern',
#                       'year_born': 1900,
#                       'year_died': 1976}),
#                     ('Jean-Paul Sartre',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jean-paul_sartre.jpg',
#                       'name': 'Jean-Paul Sartre',
#                       'time_period': 'modern',
#                       'year_born': 1905,
#                       'year_died': 1980}),
#                     ('Willard Van Orman Quine',
#                      {'Nationality': 'American',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/willard_van_orman_quine.jpg',
#                       'name': 'Willard Van Orman Quine',
#                       'time_period': 'modern',
#                       'year_born': 1908,
#                       'year_died': 2000}),
#                     ('Alfred Ayer',
#                      {'Nationality': 'English',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/alfred_ayer.jpg',
#                       'name': 'Alfred Ayer',
#                       'time_period': 'modern',
#                       'year_born': 1910,
#                       'year_died': 1989}),
#                     ('Michel Foucault',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/michel_foucault.jpg',
#                       'name': 'Michel Foucault',
#                       'time_period': 'modern',
#                       'year_born': 1926,
#                       'year_died': 1984}),
#                     ('Jacques Derrida',
#                      {'Nationality': 'French',
#                       'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jacques_derrida.jpg',
#                       'name': 'Jacques Derrida',
#                       'time_period': 'modern',
#                       'year_born': 1930,
#                       'year_died': 2004}),
#                     ('Robert Boyle',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/robert_boyle.jpg',
#                       'name': 'Robert Boyle',
#                       'time_period': 'reason',
#                       'year_born': 1627,
#                       'year_died': 1691}),
#                     ('Anne Conway',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anne_conway.jpg',
#                       'name': 'Anne Conway',
#                       'time_period': 'reason',
#                       'year_born': 1631,
#                       'year_died': 1679}),
#                     ('Anthony Ashley Cooper',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/anthony_ashley_cooper.jpg',
#                       'name': 'Anthony Ashley Cooper',
#                       'time_period': 'enlightenment',
#                       'year_born': 1671,
#                       'year_died': 1713}),
#                     ('Samuel Clarke',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/samuel_clarke.jpg',
#                       'name': 'Samuel Clarke',
#                       'time_period': 'enlightenment',
#                       'year_born': 1675,
#                       'year_died': 1729}),
#                     ('George Berkeley',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/george_berkeley.jpg',
#                       'name': 'George Berkeley',
#                       'time_period': 'enlightenment',
#                       'year_born': 1685,
#                       'year_died': 1753}),
#                     ('Joseph Butler',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/joseph_butler.jpg',
#                       'name': 'Joseph Butler',
#                       'time_period': 'enlightenment',
#                       'year_born': 1692,
#                       'year_died': 1752}),
#                     ('Francis Hutcheson',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/francis_hutcheson.jpg',
#                       'name': 'Francis Hutcheson',
#                       'time_period': 'enlightenment',
#                       'year_born': 1694,
#                       'year_died': 1746}),
#                     ('Jonathan Edwards',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/jonathan_edwards.jpg',
#                       'name': 'Jonathan Edwards',
#                       'time_period': 'enlightenment',
#                       'year_born': 1703,
#                       'year_died': 1758}),
#                     ('Julien Offray de La Mettrie',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/julien_offray_de_la_mettrie.jpg',
#                       'name': 'Julien Offray de La Mettrie',
#                       'time_period': 'enlightenment',
#                       'year_born': 1709,
#                       'year_died': 1751}),
#                     ('Thomas Reid',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/thomas_reid.jpg',
#                       'name': 'Thomas Reid',
#                       'time_period': 'enlightenment',
#                       'year_born': 1710,
#                       'year_died': 1796}),
#                     ('Richard Price',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/richard_price.jpg',
#                       'name': 'Richard Price',
#                       'time_period': 'enlightenment',
#                       'year_born': 1723,
#                       'year_died': 1791}),
#                     ('Moses Mendelssohn',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/moses_mendelssohn.jpg',
#                       'name': 'Moses Mendelssohn',
#                       'time_period': 'modern',
#                       'year_born': 1729,
#                       'year_died': 1786}),
#                     ('Nicolas de Condorcet',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/nicolas_de_condorcet.jpg',
#                       'name': 'Nicolas de Condorcet',
#                       'time_period': 'modern',
#                       'year_born': 1743,
#                       'year_died': 1794}),
#                     ('Mary Wollstonecraft',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/mary_wollstonecraft.jpg',
#                       'name': 'Mary Wollstonecraft',
#                       'time_period': 'modern',
#                       'year_born': 1759,
#                       'year_died': 1797}),
#                     ('Benjamin Constant',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/benjamin_constant.jpg',
#                       'name': 'Benjamin Constant',
#                       'time_period': 'modern',
#                       'year_born': 1767,
#                       'year_died': 1830}),
#                     ('Henry Sidgwick',
#                      {'image_path': '/Users/tylerlazoen/philosophy_capstone/images/henry_sidgwick.jpg',
#                       'name': 'Henry Sidgwick',
#                       'time_period': 'modern',
#                       'year_born': 1838,
#                       'year_died': 1900})])

# %%
phil_list = []
for key in philosophers.keys():
    philosophers[key]['name'] = key
    phil_list.append(philosophers[key])

# %%
philosophers_df = pd.DataFrame(phil_list)

# %%
philosophers_df.head()
# Out:
#   Nationality                                         image_path  \
# 0       Greek  /Users/tylerlazoen/philosophy_capstone/images/...
# 1       Greek  /Users/tylerlazoen/philosophy_capstone/images/...
# 2       Greek  /Users/tylerlazoen/philosophy_capstone/images/...
# 3       Greek  /Users/tylerlazoen/philosophy_capstone/images/...
# 4       Greek  /Users/tylerlazoen/philosophy_capstone/images/...
#
#                 name  time_period  year_born  year_died
# 0  Thales of Miletos  presocratic       -624       -546
# 1        Anaximander  presocratic       -610       -546
# 2         Anaximenes  presocratic       -585       -525
# 3         Pythagoras  presocratic       -570       -490
# 4         Heraclitus  presocratic       -535       -475

# %%
cols = list(philosophers_df)
cols.insert(0, cols.pop(cols.index('name')))
cols.insert(2, cols.pop(cols.index('time_period')))
cols.insert(3, cols.pop(cols.index('year_born')))
cols.insert(4, cols.pop(cols.index('year_died')))
cols = [x.lower() for x in cols]
philosophers_df = philosophers_df.ix[:, cols]

# %%
philosophers_df.head()
# Out:
#                 name  nationality  time_period  year_born  year_died  \
# 0  Thales of Miletos          NaN  presocratic       -624       -546
# 1        Anaximander          NaN  presocratic       -610       -546
# 2         Anaximenes          NaN  presocratic       -585       -525
# 3         Pythagoras          NaN  presocratic       -570       -490
# 4         Heraclitus          NaN  presocratic       -535       -475
#
#                                           image_path
# 0  /Users/tylerlazoen/philosophy_capstone/images/...
# 1  /Users/tylerlazoen/philosophy_capstone/images/...
# 2  /Users/tylerlazoen/philosophy_capstone/images/...
# 3  /Users/tylerlazoen/philosophy_capstone/images/...
# 4  /Users/tylerlazoen/philosophy_capstone/images/...

# %%
documents_path = '~/philosophy_capstone/data/documents.csv'
philosophers_path = '~/philosophy_capstone/data/philosophers.csv'

documents_df.to_csv(documents_path)
philosophers_df.to_csv(philosophers_path)
